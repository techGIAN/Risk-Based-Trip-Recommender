# %%
import pandas as pd

# %%
df = pd.read_csv('ca_poi_risks_2021-04-19-one-week.csv')
df.columns
# Out:
# Index(['placekey', 'safegraph_place_id', 'location_name', 'latitude',
#        'longitude', 'top_category', 'poiRisk_0', 'poiRisk_1', 'poiRisk_2',
#        'poiRisk_3',
#        ...
#        'poiRisk_158', 'poiRisk_159', 'poiRisk_160', 'poiRisk_161',
#        'poiRisk_162', 'poiRisk_163', 'poiRisk_164', 'poiRisk_165',
#        'poiRisk_166', 'poiRisk_167'],
#       dtype='object', length=174)

# %%
df.head()
# Out:
#               placekey                   safegraph_place_id  \
# 0  zzw-222@65x-9m6-qfz  sg:006a0dff74f34238b25186af152aebb8
# 1  22d-222@3wx-yd9-c5z  sg:03eef9a4da2f4fa1a062dc3e4228ae72
# 2  222-222@66b-2dy-ht9  sg:04b12c3a6eba4a6c8b40a1c1cdba1243
# 3  zzw-222@5sz-yq2-zxq  sg:0556e5faae5449429835ce62a6071bbd
# 4  222-222@665-zky-p7q  sg:0605aff4eae14a4bb50b84f634ca7384
#
#                                        location_name   latitude   longitude  \
# 0  Demenagement & Entreposage Boyd Ltee Membre De...  45.414467  -75.640502
# 1                              Dylan's Burger & Deli  49.695353 -112.839831
# 2                    Alex Plomberie & Chauffage Enrg  45.567055  -73.686813
# 3                                  Klein's Food Mart  50.489690 -104.631866
# 4                                        Side B Vibe  43.595813  -79.623489
#
#                                         top_category  poiRisk_0  poiRisk_1  \
# ...
